# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/constantinpape/torch-em/blob/main/experiments/2D-UNet-Training.ipynb)

# %% [markdown]
# # 2D UNet Training
#
# This notebook implements training of a 2D UNet with `torch_em`. It implements training for affinity, boundary and foreground prediction. The training code is also customizable to enable training with a different target.
#
# The sections of this notebook are organized s.t. there is a first cell that contains the configurable parameters. These cells are marked by the comment `#CONFIGURE ME`. The following cells contain code that do not need to be changed. But if you know what you're doing you can further customize the training there.
#
# For setting up a local environment that can run `torch_em`, follow [the installation instructions](https://github.com/constantinpape/torch-em#installation). You can also run the notebook in google colab, please follow the instructions in the first section for this.

# %% [markdown]
# ## Google Colab
#
# Run the following cells if you are working in google colab. Skip them otherwise.

# %%
# First, make sure that you are using a GPU. For this, go to:
# Runtime->Change runtime type and select Hardware accelarator->GPU
# When you then run this cell you should see a gpu status overview
# (if something went wrong you will see an error message)
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# Install conda in your google drive session
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# update conda
# !conda update conda
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.11.12 |       hbd8a1cb_0         149 KB  conda-forge
#     certifi-2025.11.12         |     pyhd8ed1ab_0         153 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     openssl-3.6.0              |       h26f9b46_0         3.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.5 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/linux-64::ca-certificates~ --> conda-forge/noarch::ca-certificates-2025.11.12-hbd8a1cb_0
#   certifi                           2024.12.14-pyhd8ed1ab_0 --> 2025.11.12-pyhd8ed1ab_0
#   conda                             24.11.2-py311h38be061_1 --> 24.11.3-py311h38be061_0
#   openssl                                  3.4.0-h7b32b05_1 --> 3.6.0-h26f9b46_0
#
#
#
# Downloading and Extracting Packages:
# openssl-3.6.0        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
# conda-24.11.3        | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# certifi-2025.11.12   | 153 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ca-certificates-2025 | 149 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# certifi-2025.11.12   | 153 KB    | :  10% 0.10426968580356517/1 [00:00<00:00,  1.02s/it]
# conda-24.11.3        | 1.1 MB    | :   1% 0.01364371451460054/1 [00:00<00:07,  8.07s/it]
#
#
# openssl-3.6.0        | 3.0 MB    | :   1% 0.005175966758061148/1 [00:00<00:22, 22.33s/it]
#
# certifi-2025.11.12   | 153 KB    | : 100% 1.0/1 [00:00<00:00,  1.02s/it]
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:00<00:00,  1.00s/it]
#
# certifi-2025.11.12   | 153 KB    | : 100% 1.0/1 [00:00<00:00,  1.02s/it]
# conda-24.11.3        | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  8.07s/it]
#
#
# openssl-3.6.0        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  5.04it/s]
# conda-24.11.3        | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  2.00it/s]
#
#
#
#
#
#
#
# done
# done
# done

# %%
# use conda to install torch-em dependencies (we don't install torch-em itseelf, in order to avoid reinstallation of pytorch)
# !conda install -c pytorch -c conda-forge python-elf dask bioimageio.core
# Out:
# Channels:
#  - pytorch
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - bioimageio.core
#     - dask
#     - python-elf
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     affogato-0.4.2             |  py311h98086f5_0        23.2 MB  conda-forge
#     annotated-types-0.7.0      |     pyhd8ed1ab_1          18 KB  conda-forge
#     anyio-4.11.0               |     pyhcf101f3_0         135 KB  conda-forge
#     aom-3.9.1                  |       hac33072_0         2.6 MB  conda-forge
#     aws-c-auth-0.8.1           |       h205f482_0         106 KB  conda-forge
#     aws-c-cal-0.8.1            |       h1a47875_3          46 KB  conda-forge
#     aws-c-common-0.10.6        |       hb9d3cd8_0         231 KB  conda-forge
#     aws-c-compression-0.3.0    |       h4e1184b_5          19 KB  conda-forge
#     aws-c-event-stream-0.5.0   |      h7959bf6_11          53 KB  conda-forge
#     aws-c-http-0.9.2           |       hefd7a92_4         193 KB  conda-forge
#     aws-c-io-0.15.3            |       h173a860_6         154 KB  conda-forge
#     aws-c-mqtt-0.11.0          |      h11f4f37_12         190 KB  conda-forge
#     aws-c-s3-0.7.9             |       he1b24dc_1         113 KB  conda-forge
#     aws-c-sdkutils-0.2.2       |       h4e1184b_0          55 KB  conda-forge
#     aws-checksums-0.2.2        |       h4e1184b_4          71 KB  conda-forge
#     aws-crt-cpp-0.29.9         |       he0e7f3f_2         345 KB  conda-forge
#     aws-sdk-cpp-1.11.489       |       h4d475cb_0         3.0 MB  conda-forge
#     azure-core-cpp-1.14.0      |       h5cfcd09_0         337 KB  conda-forge
#     azure-identity-cpp-1.10.0  |       h113e628_0         227 KB  conda-forge
#     azure-storage-blobs-cpp-12.13.0|       h3cf044e_1         536 KB  conda-forge
#     azure-storage-common-cpp-12.8.0|       h736e048_1         146 KB  conda-forge
#     azure-storage-files-datalake-cpp-12.12.0|       ha633028_1         281 KB  conda-forge
#     bioimageio.core-0.9.5      |     pyhd8ed1ab_0          74 KB  conda-forge
#     bioimageio.spec-0.5.6.0    |     pyhd8ed1ab_0         129 KB  conda-forge
#     blosc-1.21.6               |       he440d0b_1          47 KB  conda-forge
#     bokeh-3.8.1                |     pyhd8ed1ab_0         4.8 MB  conda-forge
#     brotli-1.1.0               |       hb9d3cd8_2          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hb9d3cd8_2          18 KB  conda-forge
#     brunsli-0.1                |       he3183e4_1         165 KB  conda-forge
#     c-blosc2-2.15.2            |       h3122c55_1         334 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     charls-2.4.2               |       h59595ed_0         147 KB  conda-forge
#     click-8.3.1                |     pyh707e725_0          90 KB  conda-forge
#     cloudpickle-3.1.2          |     pyhd8ed1ab_0          26 KB  conda-forge
#     coin-or-cbc-2.10.12        |       h00e76a6_2         881 KB  conda-forge
#     coin-or-cgl-0.60.9         |       h82e2f02_4         516 KB  conda-forge
#     coin-or-clp-1.17.10        |       h8a7a1e7_1         1.1 MB  conda-forge
#     coin-or-osi-0.108.11       |       h96cc833_4         357 KB  conda-forge
#     coin-or-utils-2.11.12      |       h3a12e53_2         646 KB  conda-forge
#     contourpy-1.3.3            |  py311hdf67eae_3         289 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     cytoolz-1.1.0              |  py311h49ec1c0_1         578 KB  conda-forge
#     dask-2025.11.0             |     pyhcf101f3_0          11 KB  conda-forge
#     dask-core-2025.11.0        |     pyhcf101f3_0         1.0 MB  conda-forge
#     dav1d-1.2.1                |       hd590300_0         742 KB  conda-forge
#     distributed-2025.11.0      |     pyhcf101f3_0         825 KB  conda-forge
#     dnspython-2.7.0            |     pyhff2d567_1         168 KB  conda-forge
#     email-validator-2.3.0      |     pyhd8ed1ab_0          46 KB  conda-forge
#     email_validator-2.3.0      |       hd8ed1ab_0           7 KB  conda-forge
#     et_xmlfile-2.0.0           |     pyhd8ed1ab_1          21 KB  conda-forge
#     exceptiongroup-1.3.1       |     pyhd8ed1ab_0          21 KB  conda-forge
#     fftw-3.3.10                |nompi_hf1063bd_110         2.0 MB  conda-forge
#     filelock-3.20.0            |     pyhd8ed1ab_0          18 KB  conda-forge
#     fonttools-4.60.1           |  py311h3778330_0         2.8 MB  conda-forge
#     freetype-2.14.1            |       ha770c72_0         169 KB  conda-forge
#     fsspec-2025.10.0           |     pyhd8ed1ab_0         143 KB  conda-forge
#     genericache-0.5.2          |     pyhd8ed1ab_0          14 KB  conda-forge
#     gflags-2.2.2               |    h5888daf_1005         117 KB  conda-forge
#     giflib-5.2.2               |       hd590300_0          75 KB  conda-forge
#     glog-0.7.1                 |       hbabe93e_0         140 KB  conda-forge
#     glpk-5.0                   |       h445213a_0        1023 KB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     h11-0.16.0                 |     pyhd8ed1ab_0          37 KB  conda-forge
#     h5py-3.13.0                |nompi_py311hb639ac4_100         1.3 MB  conda-forge
#     hdf5-1.14.3                |nompi_h2d575fe_109         3.7 MB  conda-forge
#     httpcore-1.0.9             |     pyh29332c3_0          48 KB  conda-forge
#     httpx-0.28.1               |     pyhd8ed1ab_0          62 KB  conda-forge
#     icu-75.1                   |       he02047a_0        11.6 MB  conda-forge
#     imagecodecs-2024.12.30     |  py311h9971d45_0         2.0 MB  conda-forge
#     imageio-2.37.0             |     pyhfb79c49_0         286 KB  conda-forge
#     imath-3.1.12               |       h7955e40_0         156 KB  conda-forge
#     importlib-metadata-8.7.0   |     pyhe01879c_1          34 KB  conda-forge
#     jinja2-3.1.6               |     pyhd8ed1ab_0         110 KB  conda-forge
#     joblib-1.5.2               |     pyhd8ed1ab_0         219 KB  conda-forge
#     jxrlib-1.1                 |       hd590300_3         234 KB  conda-forge
#     kiwisolver-1.4.9           |  py311h724c32c_2          77 KB  conda-forge
#     lazy-loader-0.4            |     pyhd8ed1ab_2          16 KB  conda-forge
#     lcms2-2.17                 |       h717163a_0         242 KB  conda-forge
#     lemon-1.3.1                |      h9457a4f_11         3.1 MB  conda-forge
#     lerc-4.0.0                 |       h0aef613_1         258 KB  conda-forge
#     libabseil-20240722.0       | cxx17_hbbce691_4         1.3 MB  conda-forge
#     libaec-1.1.4               |       h3f801dc_0          36 KB  conda-forge
#     libarrow-19.0.1            |   hfa2a6e7_0_cpu         8.6 MB  conda-forge
#     libarrow-acero-19.0.1      |   hcb10f89_0_cpu         623 KB  conda-forge
#     libarrow-dataset-19.0.1    |   hcb10f89_0_cpu         590 KB  conda-forge
#     libarrow-substrait-19.0.1  |   h08228c5_0_cpu         511 KB  conda-forge
#     libavif16-1.3.0            |       h6395336_2         136 KB  conda-forge
#     libblas-3.9.0              |31_h59b9bed_openblas          16 KB  conda-forge
#     libboost-1.86.0            |       h6c02f8c_3         2.8 MB  conda-forge
#     libboost-python-1.86.0     |  py311h1d5f577_4         118 KB  conda-forge
#     libbrotlicommon-1.1.0      |       hb9d3cd8_2          67 KB  conda-forge
#     libbrotlidec-1.1.0         |       hb9d3cd8_2          32 KB  conda-forge
#     libbrotlienc-1.1.0         |       hb9d3cd8_2         275 KB  conda-forge
#     libcblas-3.9.0             |31_he106b2a_openblas          16 KB  conda-forge
#     libcrc32c-1.1.2            |       h9c3ff4c_0          20 KB  conda-forge
#     libdeflate-1.23            |       h86f0d12_0          71 KB  conda-forge
#     libevent-2.1.12            |       hf998b51_1         417 KB  conda-forge
#     libfreetype-2.14.1         |       ha770c72_0           7 KB  conda-forge
#     libfreetype6-2.14.1        |       h73754d4_0         378 KB  conda-forge
#     libgfortran-14.2.0         |       h69a702a_2          52 KB  conda-forge
#     libgfortran-ng-14.2.0      |       h69a702a_2          53 KB  conda-forge
#     libgfortran5-14.2.0        |       hf1ad2bd_2         1.4 MB  conda-forge
#     libgoogle-cloud-2.35.0     |       h2b5623c_0         1.2 MB  conda-forge
#     libgoogle-cloud-storage-2.35.0|       h0121fbd_0         767 KB  conda-forge
#     libgrpc-1.67.1             |       h25350d4_2         7.8 MB  conda-forge
#     libhwy-1.3.0               |       h4c17acf_1         1.4 MB  conda-forge
#     libjpeg-turbo-3.1.2        |       hb03c661_0         619 KB  conda-forge
#     libjxl-0.11.1              |       h6cb5226_4         1.7 MB  conda-forge
#     liblapack-3.9.0            |31_h7ac8fdf_openblas          16 KB  conda-forge
#     liblapacke-3.9.0           |31_he2f377e_openblas          16 KB  conda-forge
#     liblzma-devel-5.6.3        |       hb9d3cd8_1         368 KB  conda-forge
#     libopenblas-0.3.29         |pthreads_h94d23a6_0         5.6 MB  conda-forge
#     libopentelemetry-cpp-1.18.0|       hfcad708_1         783 KB  conda-forge
#     libopentelemetry-cpp-headers-1.18.0|       ha770c72_1         313 KB  conda-forge
#     libparquet-19.0.1          |   h081d1f1_0_cpu         1.2 MB  conda-forge
#     libpng-1.6.51              |       h421ea60_0         310 KB  conda-forge
#     libprotobuf-5.28.3         |       h6128344_1         2.8 MB  conda-forge
#     libre2-11-2024.07.02       |       hbbce691_2         205 KB  conda-forge
#     libthrift-0.21.0           |       h0e7cc3e_0         416 KB  conda-forge
#     libtiff-4.7.0              |       hd9ff511_3         418 KB  conda-forge
#     libutf8proc-2.10.0         |       h202a827_0          81 KB  conda-forge
#     libvigra-1.12.2            |       hffb6633_0         1.0 MB  conda-forge
#     libwebp-base-1.6.0         |       hd42ef1d_0         419 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libxml2-2.13.5             |       h8d12d68_1         674 KB  conda-forge
#     libzopfli-1.0.3            |       h9c3ff4c_0         164 KB  conda-forge
#     llvmlite-0.45.0            |  py311h1741904_0        32.6 MB  conda-forge
#     locket-1.0.0               |     pyhd8ed1ab_0           8 KB  conda-forge
#     loguru-0.7.3               |     pyh707e725_0          58 KB  conda-forge
#     lz4-4.4.5                  |  py311h1c460e0_0          44 KB  conda-forge
#     markdown-3.10              |     pyhcf101f3_1          83 KB  conda-forge
#     markdown-it-py-4.0.0       |     pyhd8ed1ab_0          63 KB  conda-forge
#     markupsafe-3.0.3           |  py311h3778330_0          25 KB  conda-forge
#     matplotlib-base-3.10.8     |  py311h0f3be63_0         7.9 MB  conda-forge
#     mdurl-0.1.2                |     pyhd8ed1ab_1          14 KB  conda-forge
#     mrcfile-1.5.4              |     pyhd8ed1ab_0          38 KB  conda-forge
#     msgpack-python-1.1.2       |  py311hdf67eae_1         101 KB  conda-forge
#     munkres-1.1.4              |     pyhd8ed1ab_1          15 KB  conda-forge
#     narwhals-2.12.0            |     pyhcf101f3_0         262 KB  conda-forge
#     networkx-3.6               |     pyhcf101f3_0         1.5 MB  conda-forge
#     nifty-1.2.4                |  py311h3be124d_2         4.7 MB  conda-forge
#     nlohmann_json-3.12.0       |       h54a6638_1         133 KB  conda-forge
#     numba-0.62.1               |  py311h6220fa4_0         5.6 MB  conda-forge
#     numpy-1.26.4               |  py311h64a7726_0         7.7 MB  conda-forge
#     openexr-3.3.3              |       hff63da0_0         1.3 MB  conda-forge
#     openjpeg-2.5.3             |       h55fea9a_1         349 KB  conda-forge
#     openpyxl-3.1.5             |  py311h534898f_2         676 KB  conda-forge
#     orc-2.0.3                  |       h12ee42a_2         1.1 MB  conda-forge
#     pandas-2.3.3               |  py311hed34c8f_1        14.6 MB  conda-forge
#     partd-1.4.2                |     pyhd8ed1ab_0          20 KB  conda-forge
#     pillow-11.3.0              |  py311h98278a2_3        1021 KB  conda-forge
#     prometheus-cpp-1.3.0       |       ha5d0236_0         195 KB  conda-forge
#     psutil-7.1.3               |  py311haee01d2_0         502 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     pyarrow-19.0.1             |  py311h38be061_0          25 KB  conda-forge
#     pyarrow-core-19.0.1        |py311h4854187_0_cpu         4.5 MB  conda-forge
#     pydantic-2.11.10           |     pyh3cfb1c2_0         301 KB  conda-forge
#     pydantic-core-2.33.2       |  py311hdae7d1d_0         1.8 MB  conda-forge
#     pydantic-settings-2.12.0   |     pyh3cfb1c2_0          43 KB  conda-forge
#     pygments-2.19.2            |     pyhd8ed1ab_0         868 KB  conda-forge
#     pyparsing-3.2.5            |     pyhcf101f3_0         102 KB  conda-forge
#     python-dateutil-2.9.0.post0|     pyhe01879c_2         228 KB  conda-forge
#     python-dotenv-1.2.1        |     pyhcf101f3_0          26 KB  conda-forge
#     python-elf-0.7.3           |     pyhd8ed1ab_0         227 KB  conda-forge
#     python-tzdata-2025.2       |     pyhd8ed1ab_0         141 KB  conda-forge
#     pytz-2025.2                |     pyhd8ed1ab_0         185 KB  conda-forge
#     pywavelets-1.9.0           |  py311h0372a8f_2         3.5 MB  conda-forge
#     pyyaml-6.0.3               |  py311h3778330_0         207 KB  conda-forge
#     qhull-2020.2               |       h434a139_5         540 KB  conda-forge
#     rav1e-0.7.1                |       h8fae777_3         4.9 MB  conda-forge
#     re2-2024.07.02             |       h9925aae_2          26 KB  conda-forge
#     rich-14.2.0                |     pyhcf101f3_0         196 KB  conda-forge
#     ruyaml-0.91.0              |     pyhd8ed1ab_1          87 KB  conda-forge
#     s2n-1.5.11                 |       h072c03f_0         348 KB  conda-forge
#     scikit-image-0.25.2        |  py311hed34c8f_2        10.4 MB  conda-forge
#     scikit-learn-1.7.2         |  py311hc3e1efb_0         9.3 MB  conda-forge
#     scipy-1.16.0               |  py311h2d3ef60_0        16.1 MB  conda-forge
#     six-1.17.0                 |     pyhe01879c_1          18 KB  conda-forge
#     skan-0.13.0                |     pyhd8ed1ab_1         1.5 MB  conda-forge
#     snappy-1.2.2               |       h03e3b7b_1          45 KB  conda-forge
#     sniffio-1.3.1              |     pyhd8ed1ab_2          15 KB  conda-forge
#     sortedcontainers-2.4.0     |     pyhd8ed1ab_1          28 KB  conda-forge
#     svt-av1-3.1.2              |       hecca717_0         2.6 MB  conda-forge
#     tblib-3.2.2                |     pyhcf101f3_0          19 KB  conda-forge
#     threadpoolctl-3.6.0        |     pyhecae5ae_0          23 KB  conda-forge
#     tifffile-2025.10.16        |     pyhd8ed1ab_0         178 KB  conda-forge
#     toolz-1.1.0                |     pyhd8ed1ab_1          53 KB  conda-forge
#     tornado-6.5.2              |  py311h49ec1c0_2         850 KB  conda-forge
#     typing-extensions-4.15.0   |       h396c80c_0          89 KB  conda-forge
#     typing-inspection-0.4.2    |     pyhd8ed1ab_1          18 KB  conda-forge
#     typing_extensions-4.15.0   |     pyhcf101f3_0          50 KB  conda-forge
#     unicodedata2-17.0.0        |  py311h49ec1c0_1         399 KB  conda-forge
#     vigra-1.12.2               |       he3d224d_0         5.7 MB  conda-forge
#     xarray-2025.1.2            |     pyhd8ed1ab_0         818 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb03c661_1          15 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb03c661_1          20 KB  conda-forge
#     xyzservices-2025.11.0      |     pyhd8ed1ab_0          50 KB  conda-forge
#     xz-5.6.3                   |       hbcc6ac9_1          23 KB  conda-forge
#     xz-gpl-tools-5.6.3         |       hbcc6ac9_1          33 KB  conda-forge
#     xz-tools-5.6.3             |       hb9d3cd8_1          88 KB  conda-forge
#     yaml-0.2.5                 |       h280c20c_3          83 KB  conda-forge
#     z5py-2.0.18                |  py311h38f5ced_1         584 KB  conda-forge
#     zfp-1.0.1                  |       h909a3a2_3         271 KB  conda-forge
#     zict-3.0.0                 |     pyhd8ed1ab_1          35 KB  conda-forge
#     zipp-3.23.0                |     pyhd8ed1ab_0          22 KB  conda-forge
#     zlib-1.3.1                 |       hb9d3cd8_2          90 KB  conda-forge
#     zlib-ng-2.2.5              |       hde8ca8f_1         108 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       269.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   affogato           conda-forge/linux-64::affogato-0.4.2-py311h98086f5_0
#   annotated-types    conda-forge/noarch::annotated-types-0.7.0-pyhd8ed1ab_1
#   anyio              conda-forge/noarch::anyio-4.11.0-pyhcf101f3_0
#   aom                conda-forge/linux-64::aom-3.9.1-hac33072_0
#   aws-c-auth         conda-forge/linux-64::aws-c-auth-0.8.1-h205f482_0
#   aws-c-cal          conda-forge/linux-64::aws-c-cal-0.8.1-h1a47875_3
#   aws-c-common       conda-forge/linux-64::aws-c-common-0.10.6-hb9d3cd8_0
#   aws-c-compression  conda-forge/linux-64::aws-c-compression-0.3.0-h4e1184b_5
#   aws-c-event-stream conda-forge/linux-64::aws-c-event-stream-0.5.0-h7959bf6_11
#   aws-c-http         conda-forge/linux-64::aws-c-http-0.9.2-hefd7a92_4
#   aws-c-io           conda-forge/linux-64::aws-c-io-0.15.3-h173a860_6
#   aws-c-mqtt         conda-forge/linux-64::aws-c-mqtt-0.11.0-h11f4f37_12
#   aws-c-s3           conda-forge/linux-64::aws-c-s3-0.7.9-he1b24dc_1
#   aws-c-sdkutils     conda-forge/linux-64::aws-c-sdkutils-0.2.2-h4e1184b_0
#   aws-checksums      conda-forge/linux-64::aws-checksums-0.2.2-h4e1184b_4
#   aws-crt-cpp        conda-forge/linux-64::aws-crt-cpp-0.29.9-he0e7f3f_2
#   aws-sdk-cpp        conda-forge/linux-64::aws-sdk-cpp-1.11.489-h4d475cb_0
#   azure-core-cpp     conda-forge/linux-64::azure-core-cpp-1.14.0-h5cfcd09_0
#   azure-identity-cpp conda-forge/linux-64::azure-identity-cpp-1.10.0-h113e628_0
#   azure-storage-blo~ conda-forge/linux-64::azure-storage-blobs-cpp-12.13.0-h3cf044e_1
#   azure-storage-com~ conda-forge/linux-64::azure-storage-common-cpp-12.8.0-h736e048_1
#   azure-storage-fil~ conda-forge/linux-64::azure-storage-files-datalake-cpp-12.12.0-ha633028_1
#   bioimageio.core    conda-forge/noarch::bioimageio.core-0.9.5-pyhd8ed1ab_0
#   bioimageio.spec    conda-forge/noarch::bioimageio.spec-0.5.6.0-pyhd8ed1ab_0
#   blosc              conda-forge/linux-64::blosc-1.21.6-he440d0b_1
#   bokeh              conda-forge/noarch::bokeh-3.8.1-pyhd8ed1ab_0
#   brotli             conda-forge/linux-64::brotli-1.1.0-hb9d3cd8_2
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.1.0-hb9d3cd8_2
#   brunsli            conda-forge/linux-64::brunsli-0.1-he3183e4_1
#   c-blosc2           conda-forge/linux-64::c-blosc2-2.15.2-h3122c55_1
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   charls             conda-forge/linux-64::charls-2.4.2-h59595ed_0
#   click              conda-forge/noarch::click-8.3.1-pyh707e725_0
#   cloudpickle        conda-forge/noarch::cloudpickle-3.1.2-pyhd8ed1ab_0
#   coin-or-cbc        conda-forge/linux-64::coin-or-cbc-2.10.12-h00e76a6_2
#   coin-or-cgl        conda-forge/linux-64::coin-or-cgl-0.60.9-h82e2f02_4
#   coin-or-clp        conda-forge/linux-64::coin-or-clp-1.17.10-h8a7a1e7_1
#   coin-or-osi        conda-forge/linux-64::coin-or-osi-0.108.11-h96cc833_4
#   coin-or-utils      conda-forge/linux-64::coin-or-utils-2.11.12-h3a12e53_2
#   contourpy          conda-forge/linux-64::contourpy-1.3.3-py311hdf67eae_3
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_1
#   cytoolz            conda-forge/linux-64::cytoolz-1.1.0-py311h49ec1c0_1
#   dask               conda-forge/noarch::dask-2025.11.0-pyhcf101f3_0
#   dask-core          conda-forge/noarch::dask-core-2025.11.0-pyhcf101f3_0
#   dav1d              conda-forge/linux-64::dav1d-1.2.1-hd590300_0
#   distributed        conda-forge/noarch::distributed-2025.11.0-pyhcf101f3_0
#   dnspython          conda-forge/noarch::dnspython-2.7.0-pyhff2d567_1
#   email-validator    conda-forge/noarch::email-validator-2.3.0-pyhd8ed1ab_0
#   email_validator    conda-forge/noarch::email_validator-2.3.0-hd8ed1ab_0
#   et_xmlfile         conda-forge/noarch::et_xmlfile-2.0.0-pyhd8ed1ab_1
#   exceptiongroup     conda-forge/noarch::exceptiongroup-1.3.1-pyhd8ed1ab_0
#   fftw               conda-forge/linux-64::fftw-3.3.10-nompi_hf1063bd_110
#   filelock           conda-forge/noarch::filelock-3.20.0-pyhd8ed1ab_0
#   fonttools          conda-forge/linux-64::fonttools-4.60.1-py311h3778330_0
#   freetype           conda-forge/linux-64::freetype-2.14.1-ha770c72_0
#   fsspec             conda-forge/noarch::fsspec-2025.10.0-pyhd8ed1ab_0
#   genericache        conda-forge/noarch::genericache-0.5.2-pyhd8ed1ab_0
#   gflags             conda-forge/linux-64::gflags-2.2.2-h5888daf_1005
#   giflib             conda-forge/linux-64::giflib-5.2.2-hd590300_0
#   glog               conda-forge/linux-64::glog-0.7.1-hbabe93e_0
#   glpk               conda-forge/linux-64::glpk-5.0-h445213a_0
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   h11                conda-forge/noarch::h11-0.16.0-pyhd8ed1ab_0
#   h5py               conda-forge/linux-64::h5py-3.13.0-nompi_py311hb639ac4_100
#   hdf5               conda-forge/linux-64::hdf5-1.14.3-nompi_h2d575fe_109
#   httpcore           conda-forge/noarch::httpcore-1.0.9-pyh29332c3_0
#   httpx              conda-forge/noarch::httpx-0.28.1-pyhd8ed1ab_0
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   imagecodecs        conda-forge/linux-64::imagecodecs-2024.12.30-py311h9971d45_0
#   imageio            conda-forge/noarch::imageio-2.37.0-pyhfb79c49_0
#   imath              conda-forge/linux-64::imath-3.1.12-h7955e40_0
#   importlib-metadata conda-forge/noarch::importlib-metadata-8.7.0-pyhe01879c_1
#   jinja2             conda-forge/noarch::jinja2-3.1.6-pyhd8ed1ab_0
#   joblib             conda-forge/noarch::joblib-1.5.2-pyhd8ed1ab_0
#   jxrlib             conda-forge/linux-64::jxrlib-1.1-hd590300_3
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.9-py311h724c32c_2
#   lazy-loader        conda-forge/noarch::lazy-loader-0.4-pyhd8ed1ab_2
#   lcms2              conda-forge/linux-64::lcms2-2.17-h717163a_0
#   lemon              conda-forge/linux-64::lemon-1.3.1-h9457a4f_11
#   lerc               conda-forge/linux-64::lerc-4.0.0-h0aef613_1
#   libabseil          conda-forge/linux-64::libabseil-20240722.0-cxx17_hbbce691_4
#   libaec             conda-forge/linux-64::libaec-1.1.4-h3f801dc_0
#   libarrow           conda-forge/linux-64::libarrow-19.0.1-hfa2a6e7_0_cpu
#   libarrow-acero     conda-forge/linux-64::libarrow-acero-19.0.1-hcb10f89_0_cpu
#   libarrow-dataset   conda-forge/linux-64::libarrow-dataset-19.0.1-hcb10f89_0_cpu
#   libarrow-substrait conda-forge/linux-64::libarrow-substrait-19.0.1-h08228c5_0_cpu
#   libavif16          conda-forge/linux-64::libavif16-1.3.0-h6395336_2
#   libblas            conda-forge/linux-64::libblas-3.9.0-31_h59b9bed_openblas
#   libboost           conda-forge/linux-64::libboost-1.86.0-h6c02f8c_3
#   libboost-python    conda-forge/linux-64::libboost-python-1.86.0-py311h1d5f577_4
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.1.0-hb9d3cd8_2
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.1.0-hb9d3cd8_2
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.1.0-hb9d3cd8_2
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-31_he106b2a_openblas
#   libcrc32c          conda-forge/linux-64::libcrc32c-1.1.2-h9c3ff4c_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.23-h86f0d12_0
#   libevent           conda-forge/linux-64::libevent-2.1.12-hf998b51_1
#   libfreetype        conda-forge/linux-64::libfreetype-2.14.1-ha770c72_0
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.14.1-h73754d4_0
#   libgfortran        conda-forge/linux-64::libgfortran-14.2.0-h69a702a_2
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-14.2.0-h69a702a_2
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.2.0-hf1ad2bd_2
#   libgoogle-cloud    conda-forge/linux-64::libgoogle-cloud-2.35.0-h2b5623c_0
#   libgoogle-cloud-s~ conda-forge/linux-64::libgoogle-cloud-storage-2.35.0-h0121fbd_0
#   libgrpc            conda-forge/linux-64::libgrpc-1.67.1-h25350d4_2
#   libhwy             conda-forge/linux-64::libhwy-1.3.0-h4c17acf_1
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.1.2-hb03c661_0
#   libjxl             conda-forge/linux-64::libjxl-0.11.1-h6cb5226_4
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-31_h7ac8fdf_openblas
#   liblapacke         conda-forge/linux-64::liblapacke-3.9.0-31_he2f377e_openblas
#   liblzma-devel      conda-forge/linux-64::liblzma-devel-5.6.3-hb9d3cd8_1
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.29-pthreads_h94d23a6_0
#   libopentelemetry-~ conda-forge/linux-64::libopentelemetry-cpp-1.18.0-hfcad708_1
#   libopentelemetry-~ conda-forge/linux-64::libopentelemetry-cpp-headers-1.18.0-ha770c72_1
#   libparquet         conda-forge/linux-64::libparquet-19.0.1-h081d1f1_0_cpu
#   libpng             conda-forge/linux-64::libpng-1.6.51-h421ea60_0
#   libprotobuf        conda-forge/linux-64::libprotobuf-5.28.3-h6128344_1
#   libre2-11          conda-forge/linux-64::libre2-11-2024.07.02-hbbce691_2
#   libthrift          conda-forge/linux-64::libthrift-0.21.0-h0e7cc3e_0
#   libtiff            conda-forge/linux-64::libtiff-4.7.0-hd9ff511_3
#   libutf8proc        conda-forge/linux-64::libutf8proc-2.10.0-h202a827_0
#   libvigra           conda-forge/linux-64::libvigra-1.12.2-hffb6633_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.6.0-hd42ef1d_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libzopfli          conda-forge/linux-64::libzopfli-1.0.3-h9c3ff4c_0
#   llvmlite           conda-forge/linux-64::llvmlite-0.45.0-py311h1741904_0
#   locket             conda-forge/noarch::locket-1.0.0-pyhd8ed1ab_0
#   loguru             conda-forge/noarch::loguru-0.7.3-pyh707e725_0
#   lz4                conda-forge/linux-64::lz4-4.4.5-py311h1c460e0_0
#   markdown           conda-forge/noarch::markdown-3.10-pyhcf101f3_1
#   markdown-it-py     conda-forge/noarch::markdown-it-py-4.0.0-pyhd8ed1ab_0
#   markupsafe         conda-forge/linux-64::markupsafe-3.0.3-py311h3778330_0
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.10.8-py311h0f3be63_0
#   mdurl              conda-forge/noarch::mdurl-0.1.2-pyhd8ed1ab_1
#   mrcfile            conda-forge/noarch::mrcfile-1.5.4-pyhd8ed1ab_0
#   msgpack-python     conda-forge/linux-64::msgpack-python-1.1.2-py311hdf67eae_1
#   munkres            conda-forge/noarch::munkres-1.1.4-pyhd8ed1ab_1
#   narwhals           conda-forge/noarch::narwhals-2.12.0-pyhcf101f3_0
#   networkx           conda-forge/noarch::networkx-3.6-pyhcf101f3_0
#   nifty              conda-forge/linux-64::nifty-1.2.4-py311h3be124d_2
#   nlohmann_json      conda-forge/linux-64::nlohmann_json-3.12.0-h54a6638_1
#   numba              conda-forge/linux-64::numba-0.62.1-py311h6220fa4_0
#   numpy              conda-forge/linux-64::numpy-1.26.4-py311h64a7726_0
#   openexr            conda-forge/linux-64::openexr-3.3.3-hff63da0_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.3-h55fea9a_1
#   openpyxl           conda-forge/linux-64::openpyxl-3.1.5-py311h534898f_2
#   orc                conda-forge/linux-64::orc-2.0.3-h12ee42a_2
#   pandas             conda-forge/linux-64::pandas-2.3.3-py311hed34c8f_1
#   partd              conda-forge/noarch::partd-1.4.2-pyhd8ed1ab_0
#   pillow             conda-forge/linux-64::pillow-11.3.0-py311h98278a2_3
#   prometheus-cpp     conda-forge/linux-64::prometheus-cpp-1.3.0-ha5d0236_0
#   psutil             conda-forge/linux-64::psutil-7.1.3-py311haee01d2_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pyarrow            conda-forge/linux-64::pyarrow-19.0.1-py311h38be061_0
#   pyarrow-core       conda-forge/linux-64::pyarrow-core-19.0.1-py311h4854187_0_cpu
#   pydantic           conda-forge/noarch::pydantic-2.11.10-pyh3cfb1c2_0
#   pydantic-core      conda-forge/linux-64::pydantic-core-2.33.2-py311hdae7d1d_0
#   pydantic-settings  conda-forge/noarch::pydantic-settings-2.12.0-pyh3cfb1c2_0
#   pygments           conda-forge/noarch::pygments-2.19.2-pyhd8ed1ab_0
#   pyparsing          conda-forge/noarch::pyparsing-3.2.5-pyhcf101f3_0
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0.post0-pyhe01879c_2
#   python-dotenv      conda-forge/noarch::python-dotenv-1.2.1-pyhcf101f3_0
#   python-elf         conda-forge/noarch::python-elf-0.7.3-pyhd8ed1ab_0
#   python-tzdata      conda-forge/noarch::python-tzdata-2025.2-pyhd8ed1ab_0
#   pytz               conda-forge/noarch::pytz-2025.2-pyhd8ed1ab_0
#   pywavelets         conda-forge/linux-64::pywavelets-1.9.0-py311h0372a8f_2
#   pyyaml             conda-forge/linux-64::pyyaml-6.0.3-py311h3778330_0
#   qhull              conda-forge/linux-64::qhull-2020.2-h434a139_5
#   rav1e              conda-forge/linux-64::rav1e-0.7.1-h8fae777_3
#   re2                conda-forge/linux-64::re2-2024.07.02-h9925aae_2
#   rich               conda-forge/noarch::rich-14.2.0-pyhcf101f3_0
#   ruyaml             conda-forge/noarch::ruyaml-0.91.0-pyhd8ed1ab_1
#   s2n                conda-forge/linux-64::s2n-1.5.11-h072c03f_0
#   scikit-image       conda-forge/linux-64::scikit-image-0.25.2-py311hed34c8f_2
#   scikit-learn       conda-forge/linux-64::scikit-learn-1.7.2-py311hc3e1efb_0
#   scipy              conda-forge/linux-64::scipy-1.16.0-py311h2d3ef60_0
#   six                conda-forge/noarch::six-1.17.0-pyhe01879c_1
#   skan               conda-forge/noarch::skan-0.13.0-pyhd8ed1ab_1
#   snappy             conda-forge/linux-64::snappy-1.2.2-h03e3b7b_1
#   sniffio            conda-forge/noarch::sniffio-1.3.1-pyhd8ed1ab_2
#   sortedcontainers   conda-forge/noarch::sortedcontainers-2.4.0-pyhd8ed1ab_1
#   svt-av1            conda-forge/linux-64::svt-av1-3.1.2-hecca717_0
#   tblib              conda-forge/noarch::tblib-3.2.2-pyhcf101f3_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.6.0-pyhecae5ae_0
#   tifffile           conda-forge/noarch::tifffile-2025.10.16-pyhd8ed1ab_0
#   toolz              conda-forge/noarch::toolz-1.1.0-pyhd8ed1ab_1
#   tornado            conda-forge/linux-64::tornado-6.5.2-py311h49ec1c0_2
#   typing-extensions  conda-forge/noarch::typing-extensions-4.15.0-h396c80c_0
#   typing-inspection  conda-forge/noarch::typing-inspection-0.4.2-pyhd8ed1ab_1
#   typing_extensions  conda-forge/noarch::typing_extensions-4.15.0-pyhcf101f3_0
#   unicodedata2       conda-forge/linux-64::unicodedata2-17.0.0-py311h49ec1c0_1
#   vigra              conda-forge/linux-64::vigra-1.12.2-he3d224d_0
#   xarray             conda-forge/noarch::xarray-2025.1.2-pyhd8ed1ab_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb03c661_1
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb03c661_1
#   xyzservices        conda-forge/noarch::xyzservices-2025.11.0-pyhd8ed1ab_0
#   xz                 conda-forge/linux-64::xz-5.6.3-hbcc6ac9_1
#   xz-gpl-tools       conda-forge/linux-64::xz-gpl-tools-5.6.3-hbcc6ac9_1
#   xz-tools           conda-forge/linux-64::xz-tools-5.6.3-hb9d3cd8_1
#   yaml               conda-forge/linux-64::yaml-0.2.5-h280c20c_3
#   z5py               conda-forge/linux-64::z5py-2.0.18-py311h38f5ced_1
#   zfp                conda-forge/linux-64::zfp-1.0.1-h909a3a2_3
#   zict               conda-forge/noarch::zict-3.0.0-pyhd8ed1ab_1
#   zipp               conda-forge/noarch::zipp-3.23.0-pyhd8ed1ab_0
#   zlib               conda-forge/linux-64::zlib-1.3.1-hb9d3cd8_2
#   zlib-ng            conda-forge/linux-64::zlib-ng-2.2.5-hde8ca8f_1
#
# The following packages will be DOWNGRADED:
#
#   libxml2                                 2.13.5-h0d44e9d_1 --> 2.13.5-h8d12d68_1
#
#
#
# Downloading and Extracting Packages:
# llvmlite-0.45.0      | 32.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
# affogato-0.4.2       | 23.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# scipy-1.16.0         | 16.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# pandas-2.3.3         | 14.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# icu-75.1             | 11.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# scikit-image-0.25.2  | 10.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# scikit-learn-1.7.2   | 9.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libarrow-19.0.1      | 8.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 7.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 7.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# vigra-1.12.2         | 5.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.62.1         | 5.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.7.1          | 4.9 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.8.1          | 4.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nifty-1.2.4          | 4.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-19.0.1  | 4.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# llvmlite-0.45.0      | 32.6 MB   | :   0% 0.000479845338912004/1 [00:00<04:23, 263.35s/it]
#
#
#
# icu-75.1             | 11.6 MB   | :   0% 0.00135078949540213/1 [00:00<01:31, 91.91s/it]
#
# scipy-1.16.0         | 16.1 MB   | :   0% 0.0009680595876600291/1 [00:00<02:55, 175.99s/it]
#
#
# llvmlite-0.45.0      | 32.6 MB   | :  14% 0.13723576692883313/1 [00:00<00:01,  1.38s/it]
#
#
#
# icu-75.1             | 11.6 MB   | :  35% 0.34985447930915164/1 [00:00<00:00,  1.87it/s]
# affogato-0.4.2       | 23.2 MB   | :   0% 0.0006747073409550609/1 [00:00<05:51, 351.39s/it]
#
# llvmlite-0.45.0      | 32.6 MB   | :  26% 0.25671725631792214/1 [00:00<00:00,  1.08s/it]
#
#
#
# icu-75.1             | 11.6 MB   | :  68% 0.676745537196467/1 [00:00<00:00,  2.47it/s]
# affogato-0.4.2       | 23.2 MB   | :  13% 0.12954380946337168/1 [00:00<00:01,  2.06s/it]
#
# scipy-1.16.0         | 16.1 MB   | :  45% 0.4482115890865935/1 [00:00<00:00,  1.51it/s]
#
#
# llvmlite-0.45.0      | 32.6 MB   | :  36% 0.35556539613379495/1 [00:00<00:00,  1.06s/it]
#
#
#
# icu-75.1             | 11.6 MB   | :  99% 0.9914794896251633/1 [00:00<00:00,  2.73it/s]
# affogato-0.4.2       | 23.2 MB   | :  27% 0.26853352170011424/1 [00:00<00:00,  1.25s/it]
#
# scipy-1.16.0         | 16.1 MB   | :  64% 0.6437596257939193/1 [00:00<00:00,  1.67it/s]
#
#
# llvmlite-0.45.0      | 32.6 MB   | :  45% 0.4534538452718438/1 [00:00<00:00,  1.06s/it]
# affogato-0.4.2       | 23.2 MB   | :  45% 0.4500297964170256/1 [00:00<00:00,  1.13it/s]
#
# scipy-1.16.0         | 16.1 MB   | :  87% 0.866413330955726/1 [00:00<00:00,  1.86it/s]
#
#
# llvmlite-0.45.0      | 32.6 MB   | :  58% 0.5758144066944048/1 [00:00<00:00,  1.04it/s]
# affogato-0.4.2       | 23.2 MB   | :  60% 0.6031883628138245/1 [00:00<00:00,  1.26it/s]
#
#
#
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:00<00:00,  2.73it/s]
#
#
# pandas-2.3.3         | 14.6 MB   | : 100% 0.99557776370209/1 [00:00<00:00,  1.95it/s]
#
#
#
#
# scikit-image-0.25.2  | 10.4 MB   | :   0% 0.0015003270060875696/1 [00:00<07:54, 474.94s/it]
# llvmlite-0.45.0      | 32.6 MB   | :  68% 0.6813803812550456/1 [00:00<00:00,  1.01s/it]
#
#
#
#
# scikit-image-0.25.2  | 10.4 MB   | :  24% 0.24455330199227382/1 [00:00<00:01,  2.46s/it]
# llvmlite-0.45.0      | 32.6 MB   | :  78% 0.7821479024265665/1 [00:00<00:00,  1.11s/it]
#
#
#
#
# llvmlite-0.45.0      | 32.6 MB   | :  89% 0.8853146502926473/1 [00:00<00:00,  1.07s/it]
#
# scipy-1.16.0         | 16.1 MB   | : 100% 1.0/1 [00:01<00:00,  1.86it/s]
#
#
#
#
# scikit-image-0.25.2  | 10.4 MB   | :  82% 0.822179199335988/1 [00:01<00:00,  1.33it/s]
#
#
#
#
#
# llvmlite-0.45.0      | 32.6 MB   | :  98% 0.9808038727361361/1 [00:01<00:00,  1.11s/it]
#
#
# pandas-2.3.3         | 14.6 MB   | : 100% 1.0/1 [00:01<00:00,  1.95it/s]
#
#
#
#
#
#
# libarrow-19.0.1      | 8.6 MB    | :   0% 0.0018269789391166852/1 [00:01<10:32, 633.91s/it]
#
#
#
#
#
# scikit-learn-1.7.2   | 9.3 MB    | :  30% 0.3047281129396279/1 [00:01<00:01,  2.77s/it]
#
#
#
#
#
#
# libarrow-19.0.1      | 8.6 MB    | :  26% 0.2557770514763359/1 [00:01<00:02,  3.57s/it]
#
#
#
#
#
# scikit-learn-1.7.2   | 9.3 MB    | :  50% 0.500624756972246/1 [00:01<00:00,  1.69s/it]
#
#
#
#
# scikit-image-0.25.2  | 10.4 MB   | : 100% 1.0/1 [00:01<00:00,  1.33it/s]
#
#
#
#
#
#
# libarrow-19.0.1      | 8.6 MB    | :  58% 0.5791523236999891/1 [00:01<00:00,  1.47s/it]
#
#
#
#
#
# scikit-learn-1.7.2   | 9.3 MB    | :  75% 0.745076979440299/1 [00:01<00:00,  1.10s/it]
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    | :   0% 0.001974389573911932/1 [00:01<11:31, 693.30s/it]
#
#
#
#
#
#
# libarrow-19.0.1      | 8.6 MB    | :  88% 0.8769498907760088/1 [00:01<00:00,  1.05it/s]
#
#
#
#
#
# scikit-learn-1.7.2   | 9.3 MB    | :  98% 0.9811575504539669/1 [00:01<00:00,  1.19it/s]
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    | :  16% 0.1618999450607784/1 [00:01<00:05,  6.59s/it]
# affogato-0.4.2       | 23.2 MB   | : 100% 1.0/1 [00:01<00:00,  1.36it/s]
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 7.8 MB    | :   0% 0.0019999599617390473/1 [00:01<12:43, 765.50s/it]
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    | :  49% 0.48569983518233517/1 [00:01<00:00,  1.93s/it]
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 7.8 MB    | :  25% 0.2459950752939028/1 [00:01<00:03,  4.77s/it]
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    | :  79% 0.7897558295647726/1 [00:01<00:00,  1.13s/it]
#
#
#
#
#
#
# libarrow-19.0.1      | 8.6 MB    | : 100% 1.0/1 [00:01<00:00,  1.05it/s]
#
#
#
#
#
# scikit-learn-1.7.2   | 9.3 MB    | : 100% 1.0/1 [00:01<00:00,  1.19it/s]
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 7.7 MB    | :   0% 0.002031269952850832/1 [00:01<14:07, 849.13s/it]
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 7.8 MB    | :  60% 0.6019879484834532/1 [00:01<00:00,  1.74s/it]
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 7.7 MB    | :  31% 0.314846842691879/1 [00:01<00:02,  4.16s/it]
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 7.8 MB    | :  94% 0.9419811419790912/1 [00:01<00:00,  1.05s/it]
#
#
#
#
#
#
#
#
#
# llvmlite-0.45.0      | 32.6 MB   | : 100% 1.0/1 [00:01<00:00,  1.11s/it]
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    | : 100% 1.0/1 [00:01<00:00,  1.13s/it]
#
#
#
#
#
#
#
#
#
#
# vigra-1.12.2         | 5.7 MB    | :   0% 0.0027405756747814515/1 [00:01<11:48, 710.10s/it]
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :   0% 0.0027679004637044184/1 [00:01<11:53, 715.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.62.1         | 5.6 MB    | :   0% 0.002805897453901523/1 [00:01<11:45, 707.51s/it]
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 7.7 MB    | :  93% 0.9262590984999796/1 [00:02<00:00,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
# vigra-1.12.2         | 5.7 MB    | :  51% 0.5070064998345685/1 [00:02<00:01,  2.89s/it]
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 7.8 MB    | : 100% 1.0/1 [00:02<00:00,  1.05s/it]
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :  41% 0.41241716909195836/1 [00:02<00:02,  3.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.62.1         | 5.6 MB    | :  55% 0.5527617984186001/1 [00:02<00:01,  2.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.7.1          | 4.9 MB    | :   0% 0.003164969597244869/1 [00:02<11:05, 667.59s/it]
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :  87% 0.866352845139483/1 [00:02<00:00,  1.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.7.1          | 4.9 MB    | :  38% 0.3766313820721394/1 [00:02<00:02,  4.20s/it]
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 7.7 MB    | : 100% 1.0/1 [00:02<00:00,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
# vigra-1.12.2         | 5.7 MB    | : 100% 1.0/1 [00:02<00:00,  1.48s/it]
#
#
#
#
#
#
#
#
#
#
# vigra-1.12.2         | 5.7 MB    | : 100% 1.0/1 [00:02<00:00,  1.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.8.1          | 4.8 MB    | :   0% 0.0032591821648894734/1 [00:02<11:44, 706.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.62.1         | 5.6 MB    | : 100% 1.0/1 [00:02<00:00,  1.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.62.1         | 5.6 MB    | : 100% 1.0/1 [00:02<00:00,  1.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nifty-1.2.4          | 4.7 MB    | :   0% 0.0033591908745808446/1 [00:02<11:40, 702.68s/it]
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:02<00:00,  1.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-19.0.1  | 4.5 MB    | :   0% 0.003465760176334087/1 [00:02<11:25, 687.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.8.1          | 4.8 MB    | :  37% 0.37480594896228947/1 [00:02<00:02,  4.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | :   0% 0.004168874001991818/1 [00:02<09:36, 579.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nifty-1.2.4          | 4.7 MB    | :  53% 0.5273929673091926/1 [00:02<00:01,  3.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.7.1          | 4.9 MB    | : 100% 1.0/1 [00:02<00:00,  1.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.7.1          | 4.9 MB    | : 100% 1.0/1 [00:02<00:00,  1.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-19.0.1  | 4.5 MB    | :  43% 0.4297542618654268/1 [00:02<00:02,  4.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.8.1          | 4.8 MB    | :  76% 0.7626486265841368/1 [00:02<00:00,  2.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | :  46% 0.4585761402191/1 [00:02<00:02,  3.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nifty-1.2.4          | 4.7 MB    | :  96% 0.9607285901301215/1 [00:02<00:00,  1.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-19.0.1  | 4.5 MB    | :  95% 0.953084048491874/1 [00:02<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nifty-1.2.4          | 4.7 MB    | : 100% 1.0/1 [00:02<00:00,  1.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.8.1          | 4.8 MB    | : 100% 1.0/1 [00:02<00:00,  2.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-19.0.1  | 4.5 MB    | : 100% 1.0/1 [00:02<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | : 100% 1.0/1 [00:02<00:00,  1.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | : 100% 1.0/1 [00:02<00:00,  1.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:03<00:00,  2.73it/s]
#
# scipy-1.16.0         | 16.1 MB   | : 100% 1.0/1 [00:07<00:00,  1.86it/s]
#
#
#
#
# scikit-image-0.25.2  | 10.4 MB   | : 100% 1.0/1 [00:08<00:00,  1.33it/s]
# affogato-0.4.2       | 23.2 MB   | : 100% 1.0/1 [00:08<00:00,  1.36it/s]
#
#
# pandas-2.3.3         | 14.6 MB   | : 100% 1.0/1 [00:09<00:00,  1.95it/s]
#
#
#
#
#
#
# libarrow-19.0.1      | 8.6 MB    | : 100% 1.0/1 [00:09<00:00,  1.05it/s]
#
#
#
#
#
# llvmlite-0.45.0      | 32.6 MB   | : 100% 1.0/1 [00:11<00:00,  1.11s/it]
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    | : 100% 1.0/1 [00:11<00:00,  1.13s/it]
#
#
#
#
#
#
#
#
# libgrpc-1.67.1       | 7.8 MB    | : 100% 1.0/1 [00:11<00:00,  1.05s/it]
#
#
#
#
#
#
#
#
#
#
# vigra-1.12.2         | 5.7 MB    | : 100% 1.0/1 [00:12<00:00,  1.48s/it]
#
#
#
#
#
#
#
#
#
# numpy-1.26.4         | 7.7 MB    | : 100% 1.0/1 [00:12<00:00,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:13<00:00,  1.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.62.1         | 5.6 MB    | : 100% 1.0/1 [00:13<00:00,  1.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# rav1e-0.7.1          | 4.9 MB    | : 100% 1.0/1 [00:16<00:00,  1.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nifty-1.2.4          | 4.7 MB    | : 100% 1.0/1 [00:16<00:00,  1.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# bokeh-3.8.1          | 4.8 MB    | : 100% 1.0/1 [00:17<00:00,  2.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyarrow-core-19.0.1  | 4.5 MB    | : 100% 1.0/1 [00:17<00:00,  1.63s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | : 100% 1.0/1 [00:17<00:00,  1.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
# use pip to install dependencies that need pytorch, including torch-em
# !pip install --no-deps kornia
# !pip install --no-deps git+https://github.com/constantinpape/torch-em
# Out:
# Collecting kornia
#   Downloading kornia-0.8.2-py2.py3-none-any.whl.metadata (18 kB)
# Downloading kornia-0.8.2-py2.py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.5 MB/s eta 0:00:00
# Installing collected packages: kornia
# Successfully installed kornia-0.8.2
# Collecting git+https://github.com/constantinpape/torch-em
#   Cloning https://github.com/constantinpape/torch-em to /tmp/pip-req-build-hfo0lu33
#   Running command git clone --filter=blob:none --quiet https://github.com/constantinpape/torch-em /tmp/pip-req-build-hfo0lu33
#   Resolved https://github.com/constantinpape/torch-em to commit 2c24336c04413be5cc3c2addb2082f3338dec026
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: torch_em
#   Building wheel for torch_em (pyproject.toml) ... done
#   Created wheel for torch_em: filename=torch_em-0.7.12-py3-none-any.whl size=538626 sha256=af3a9e498f17d303250317cd73a97faafe74563d2d38a7a2d9f665a7928f5525
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2_ukpwag/wheels/58/1e/c6/7a45f181adc4f524d6ab615f79204ecd9f043b85f12fc2b7a4
# Successfully built torch_em
# Installing collected packages: torch_em
# Successfully installed torch_em-0.7.12

# %%
# mount your google drive to permanently save data
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Imports
#
# Import the required libraries, no need to change anything here.

# %%
# load tensorboard extension
# we will need this later in the notebook to monitor the training progress
# %load_ext tensorboard

# %%
# !pip install torch-em
# Out:
# Requirement already satisfied: torch-em in /usr/local/lib/python3.11/site-packages (0.7.12)
# Collecting torch (from torch-em)
#   Downloading torch-2.9.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/site-packages (from torch-em) (3.13.0)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.11/site-packages (from h5py->torch-em) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from torch->torch-em) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/site-packages (from torch->torch-em) (4.15.0)
# Collecting sympy>=1.13.3 (from torch->torch-em)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.11/site-packages (from torch->torch-em) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch->torch-em) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.11/site-packages (from torch->torch-em) (2025.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch->torch-em)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch->torch-em)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch->torch-em)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch->torch-em)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch->torch-em)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch->torch-em)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch->torch-em)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch->torch-em)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch->torch-em)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch->torch-em)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch->torch-em)
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch->torch-em)
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch->torch-em)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch->torch-em)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch->torch-em)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.5.1 (from torch->torch-em)
#   Downloading triton-3.5.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch->torch-em)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->torch->torch-em) (3.0.3)
# Downloading torch-2.9.1-cp311-cp311-manylinux_2_28_x86_64.whl (899.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 28.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 46.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 167.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 68.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 41.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 15.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 65.5 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 52.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 65.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 71.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 18.1 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 16.2 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 18.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 67.5 MB/s eta 0:00:00
# Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 64.1 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.5.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.4/170.4 MB 37.6 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 93.5 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 15.8 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, triton, sympy, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch

# %%
import numpy as np
import torch.nn as nn
import torch_em
import torch_em.data.datasets as torchem_data
from torch_em.model import UNet2d
from torch_em.util.debug import check_loader, check_trainer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1201270730.py in <cell line: 0>()
#       1 import numpy as np
#       2 import torch.nn as nn
# ----> 3 import torch_em
#       4 import torch_em.data.datasets as torchem_data
#       5 from torch_em.model import UNet2d
#
# ModuleNotFoundError: No module named 'torch_em'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Training Data
#
# Choose the dataset for training. You have two options here: choose a preconfigured dataset or specify the filepaths to your training data.
#
# For preconfigured datasets `torch_em` implements download and default pre-processing already. The following pre-configured datasets are currently available:
# - `covid_if`: Cells imaged via immunofluorescence.
# - `dsb`: Nuclei imaged via fluorescence.
# - `hpa`: Data from the human protein atlas.
# - `isbi2012`: Neural tissue imaged in electron microscopy.
# - `livecell`: Cells imaged in phase-contrast microscopy.
# - `vnc-mitos`: Mitochondria imaged in electron microscopy.
#
# If you're unsure if one of these datasets is suitable for you, just select it and continue to `Check training data` with the default settings in the next sections. You will see example images from the data there.
#
# You can also load the training data from local files. `torch_em` supports loading data from different formats, the two easiest options are:
# - single images: store images and labels in two separate folder using a common image format such as png or tif. The corresponding data and label files should have the same filename.
#     - set `data_paths` to the filepath of the folder with the images, `label_paths` to the path of the folder with the labels
#     - set `data_key` and `label_key` to `*.<FILE_EXTENSION>`, e.g. `*.tif` for tif files.
# - image stacks: store the image and label stack(s) as hdf5, zarr or n5 data.
#     - set `data_paths` to the filepath of the image data stack and `label_paths` to the path of the label data stack; you can also provide a list of file paths if you have multiple stacks
#     - set `data_key` and `label_key` to the corresponding paths in file.
#
# You can find examples for the custom datasets in the comments below.
#
# You also need to choose `patch_shape`, which determines the size of the patches used for training, here.

# %%
# CONFIGURE ME

#
# use a pre-configured dataset
#

# Specify a pre-configured dataset. Set to `None` in order to specify the training data via file-paths instead.
preconfigured_dataset = None

# example: use the pre-configured `dsb` dataset
# preconfigured_dataset = "dsb"

# Where to download the training data (the data will be downloaded only once).
# If you work in google colab you may want to adapt this path to be on your google drive, in order
# to not loose the data after each session.
download_folder = f"./training_data/{preconfigured_dataset}"

#
# use a custom dataset
#

# Create a custom dataset from local data by specifiying the paths for training data, training labels
# as well as validation data and validation labels
train_data_paths = []
val_data_paths = []
data_key = ""
train_label_paths = []
val_label_paths = []
label_key = ""

# In addition you can also specify region of interests for training using the normal python slice syntax
train_rois = None
val_rois = None

# example 1: Use training raw data and labels stored as tif-images in separate folders.
# The example is formulated using the data from the `dsb` dataset.

# train_data_paths = "./training_data/dsb/train/images"
# val_data_paths = "./training_data/dsb/test/images"
# data_key = "*.tif"
# train_label_paths = "./training_data/dsb/train/masks"
# val_label_paths = "./training_data/dsb/test/masks"
# label_key = "*.tif"
# patch_shape = (256, 256)

# example 2: Use training data and labels stored as a single stack in an hdf5 file.
# This example is formulated using the data from the `vnc-mitos` dataset,
# which stores the raw data in `/raw` and the labels in `/labels/mitochondria`.
# Note that we use roi's here to get separate training and val data from the same file.
# train_data_paths etc. can also be lists in order to train from multiple stacks.

# train_data_paths = train_label_paths = val_data_paths = val_label_paths = "./training_data/vnc-mitos/vnc_train.h5"
# data_key = "/raw"
# label_key = "/labels/mitochondria"
# train_rois = np.s_[:18, :, :]
# val_rois = np.s_[18:, :, :]
# patch_shape = (1, 512, 512)

#
# choose the patch shape
#

# This should be chosen s.t. it is smaller than the smallest image in your training data.
# If you are training from 3d data (data with a z-axis), you will need to specify the patch_shape
# as (1, shape_y, shape_x).
patch_shape = (512, 512)

# %%
dataset_names = [
    "covid_if", "dsb", "hpa", "isbi2012", "livecell", "vnc-mitos"
]


def check_data(data_paths, label_paths, rois):
    print("Loading the raw data from:", data_paths, data_key)
    print("Loading the labels from:", label_paths, label_key)
    try:
        torch_em.default_segmentation_dataset(data_paths, data_key, label_paths, label_key, patch_shape, rois=rois)
    except Exception as e:
        print("Loading the dataset failed with:")
        raise e

if preconfigured_dataset is None:
    print("Using a custom dataset:")
    print("Checking the training dataset:")
    check_data(train_data_paths, train_label_paths, train_rois)
    check_data(val_data_paths, val_label_paths, val_rois)
else:
    assert preconfigured_dataset in dataset_names, f"Invalid pre-configured dataset: {preconfigured_dataset}, choose one of {dataset_names}."
    if preconfigured_dataset in ("isbi2012", "vnc-mitos") and len(patch_shape) == 2:
        patch_shape = (1,) + patch_shape

assert len(patch_shape) in (2, 3)

# %% [markdown]
# ## Network output
#
# Choose the transformations applied to your label data in order to generate the network target data. If your labels can be fed to the network directly you don't need to do anything here. Otherwise, you can choose between the following transformations:
# - `foreground`: transforms labels into a binary target
# - `affinities`: transforms labels into affinity target
# - `boundaries`: transforms labels into boundary target
#
# Note that `affinities` and `boundaries` are mutually exclusive; `foreground` can be combined with the two other transformations. All three transformations are implemented to be applied to *instance labels*. See the screenshot below for an illustration of the expected input and the result of these transformations. You will see their result for your own datain in `Check training data`.
#
# ![targets](https://github.com/constantinpape/torch-em/blob/main/experiments/misc/targets.png?raw=1)

# %%
# CONFIGURE ME

# Whether to add a foreground channel (1 for all labels that are not zero) to the target.
foreground = False
# Whether to add affinity channels (= directed boundaries) or a boundary channel to the target.
# Note that you can choose at most of these two options.
affinities = False
boundaries = False

# the pixel offsets that are used to compute the affinity channels
offsets = [[-1, 0], [0, -1], [-3, 0], [0, -3], [-9, 0], [0, -9]]

# %%
assert not (affinities and boundaries), "Predicting both affinities and boundaries is not supported"

label_transform, label_transform2 = None, None
if affinities:
    label_transform2 = torch_em.transform.label.AffinityTransform(
        offsets=offsets, add_binary_target=foreground, add_mask=True
    )
elif boundaries:
    label_transform = torch_em.transform.label.BoundaryTransform(
        add_binary_target=foreground
    )
elif foreground:
    label_transform = torch_em.transform.label.labels_to_binary

# %% [markdown]
# ## Loss, metric & batch size
#
# Choose important training parameters:
#
# - `loss`: the loss function; can be one of `"bce", "ce", "dice"` (binary cross entropy, cross entropy, dice) or a torch module
# - `metric`: the metric used for the validation data; same options as for `loss`
# - `batch_size`: the training batch size
#
# If you're unsure about these settings just use the default values, they are probably ok.

# %%
# CONFIGURE ME
batch_size = 1
loss = "dice"
metric = "dice"

# %%
def get_loss(loss_name):
    loss_names = ["bce", "ce", "dice"]
    if isinstance(loss_name, str):
        assert loss_name in loss_names, f"{loss_name}, {loss_names}"
        if loss_name == "dice":
            loss_function = torch_em.loss.DiceLoss()
        elif loss == "ce":
            loss_function = nn.CrossEntropyLoss()
        elif loss == "bce":
            loss_function = nn.BCEWithLogitsLoss()
    else:
        loss_function = loss_name

    # we need to add a loss wrapper for affinities
    if affinities:
        loss_function = torch_em.loss.LossWrapper(
            loss_function, transform=torch_em.loss.ApplyAndRemoveMask()
        )
    return loss_function


loss_function = get_loss(loss)
metric_function = get_loss(metric)

kwargs = dict(
    ndim=2, patch_shape=patch_shape, batch_size=batch_size,
    label_transform=label_transform, label_transform2=label_transform2
)
ds = preconfigured_dataset

if ds is None:
    train_loader = torch_em.default_segmentation_loader(
        train_data_paths, data_key, train_label_paths, label_key,
        rois=train_rois, **kwargs
    )
    val_loader = torch_em.default_segmentation_loader(
        val_data_paths, data_key, val_label_paths, label_key,
        rois=val_rois, **kwargs
    )
else:
    kwargs.update(dict(download=True))
    if ds == "covid_if":
        # use first 5 images for validation and the rest for training
        train_range, val_range = (5, None), (0, 5)
        train_loader = torchem_data.get_covid_if_loader(download_folder, sample_range=train_range, **kwargs)
        val_loader = torchem_data.get_covid_if_loader(download_folder, sample_range=val_range, **kwargs)
    elif ds == "dsb":
        train_loader = torchem_data.get_dsb_loader(download_folder, split="train", **kwargs)
        val_loader = torchem_data.get_dsb_loader(download_folder, split="train", **kwargs)
    elif ds == "hpa":
        train_loader = torchem_data.get_hpa_segmentation_loader(download_folder, split="train", **kwargs)
        val_loader = torchem_data.get_hpa_segmentation_loader(download_folder, split="val", **kwargs)
    elif ds == "isbi2012":
        assert not foreground, "Foreground prediction for the isbi neuron segmentation data does not make sense, please change these setings"
        train_roi, val_roi = np.s_[:28, :, :], np.s_[28:, :, :]
        train_loader = torchem_data.get_isbi_loader(download_folder, rois=train_roi, **kwargs)
        val_loader = torchem_data.get_isbi_loader(download_folder, rois=val_roi, **kwargs)
    elif ds == "livecell":
        train_loader = torchem_data.get_livecell_loader(download_folder, split="train", **kwargs)
        val_loader = torchem_data.get_livecell_loader(download_folder, split="val", **kwargs)
    # monuseg is not fully implemented yet
    # elif ds == "monuseg":
    #     train_loader = torchem_data.get
    elif ds == "vnc-mitos":
        train_roi, val_roi = np.s_[:18, :, :], np.s_[18:, :, :]
        train_loader = torchem_data.get_vnc_mito_loader(download_folder, rois=train_roi, **kwargs)
        val_loader = torchem_data.get_vnc_mito_loader(download_folder, rois=val_roi, **kwargs)

assert train_loader is not None, "Something went wrong"
assert val_loader is not None, "Something went wrong"

# %% [markdown]
# ## Check training data
#
# Check the output from your data loader. It consists of the input data for your network and the target data.
# You should check that the target looks reasonable.

# %%
# CONFIGURE ME

# choose the number of samples to check per loader
n_samples = 4

# %%
print("Training samples")
check_loader(train_loader, n_samples, plt=True)
print("Validation samples")
check_loader(val_loader, n_samples, plt=True)

# %% [markdown]
# ## Network architecture
#
# Choose the important network architecture parameters for the 2d UNet:
# - `depth`: the number of decoder / encoder levels
# - `initial_features`: the number of features in the first encoder level, the number will be doubled for each level
# - `final_activation`: the activation applied to the UNet output
# - `in_channels`: the number of input channels (= number of channels of the raw data)
# - `out_channels`: the number of output channels (usually the number of target channels)
#
# If you're unsure about these settings just use the default values, they are probably ok.

# %%
# CONFIGURE ME
depth = 4
initial_features = 32
final_activation = None

# If you leave the in/out_channels as None an attempt will be made to automatically deduce these numbers.
in_channels = None
out_channels = None

# %%
if final_activation is None and loss == "dice":
    final_activation = "Sigmoid"
    print("Adding a sigmoid activation because we are using dice loss")

if in_channels is None:
    in_channels = 1

if out_channels is None:
    if affinities:
        n_off = len(offsets)
        out_channels = n_off + 1 if foreground else n_off
    elif boundaries:
        out_channels = 2 if foreground else 1
    elif foreground:
        out_channels = 1
    assert out_channels is not None, "The number of out channels could not be deduced automatically. Please set it manually in the cell above."

print("Creating 2d UNet with", in_channels, "input channels and", out_channels, "output channels.")
model = UNet2d(
    in_channels=in_channels, out_channels=out_channels, depth=depth, final_activation=final_activation
)

# %% [markdown]
# ## Tensorboard
#
# Start the tensorboard in order to keep track of the training progress.

# %%
# %tensorboard --logdir logs

# %% [markdown]
# ## Training
#
# Choose additional training parameter:
# - `experiment_name`: the name for this training run, which will be used for naming the checkpoint for this model and for identifying the model in tensorboard.
# - `n_iterations`: number of iterations to train for.
# - `learning_rate`: the learning rate for gradient based updates.
#
# This also starts the training!
#
# **Important:** If you're on google colab the checkpoint will not be saved permanently. To save it you will need to copy the local folder `checkpoints` to your google drive.

# %%
# CONFIGURE ME
experiment_name = "my-shiny-net"
n_iterations = 10000
learning_rate = 1.0e-4

# %%
# IMPORTANT! if your session on google colab crashes here, you will need to uncomment the 'logger=None' comment
# in this case you can't use tensorboard, but everything else will work as expected
# (this happens due to incompatible google protobuf versions and I don't have time to fix this right now)
trainer = torch_em.default_segmentation_trainer(
    name=experiment_name, model=model,
    train_loader=train_loader, val_loader=val_loader,
    loss=loss_function, metric=metric_function,
    learning_rate=learning_rate,
    mixed_precision=True,
    log_image_interval=50,
    # logger=None
)
trainer.fit(n_iterations)

# %% [markdown]
# ## Check trained network
#
# Look at predictions from the trained network and their comparison to the target.

# %%
# CONFIGURE ME
n_samples = 2

# %%
check_trainer(trainer, n_samples, plt=True)

# %% [markdown]
# ## Export network to bioimage.io format
#
# Finally, you can export the trained model in the format compatible with [BioImage.IO](https://bioimage.io/#/), a modelzoo for bioimage analysis. After exporting, you can upload the model there to share it with other researchers.
# You only need to configure where to save the model via `export_folder` and whether to convert it to additional formats via `additional_weight_formats` and you will be prompted to enter additional information when you run the second cell. You should also write some documentation for the model in `doc`.

# %%
# CONFIGURE ME

# The folder where the bioimageio model will be saved (as a .zip file).
# If you run in google colab you should adapt this path to your google drive so that you can download the saved model.
export_folder = "./my-fancy-bio-model"

# Whether to convert the model weights to additional formats.
# Currently, torchscript and onnx are support it and this will enable running the model
# in more software tools.
additional_weight_formats = None
# additional_weight_formats = ["torchscript"]

doc = None
# write some markdown documentation like this, otherwise a default documentation text will be used
# doc = """#My Fancy Model
# This is a fancy model to segment shiny objects in images.
# """

# %%
import torch_em.util.modelzoo

for_dij = additional_weight_formats is not None and "torchscript" in additional_weight_formats

training_data = None
if preconfigured_dataset is not None:
    if preconfigured_dataset == "vnc-mitos":
        data_id = torchem_data.get_bioimageio_dataset_id("vnc")
    else:
        data_id = torchem_data.get_bioimageio_dataset_id(preconfigured_dataset)
    if data_id:
        training_data = {"id": data_id}

pred_str = ""
if affinities:
    pred_str = "affinities and foreground probabilities" if foreground else "affinities"
elif boundaries:
    pred_str = "boundary and foreground probabilities" if foreground else "boundaries"
elif foreground:
    pred_str = "foreground"

default_doc = f"""#{experiment_name}

This model was trained with [the torch_em 2d UNet notebook](https://github.com/constantinpape/torch-em/blob/main/experiments/2D-UNet-Training.ipynb).
"""
if pred_str:
    default_doc += f"It predicts {pred_str}.\n"

training_summary = torch_em.util.get_training_summary(trainer, to_md=True, lr=learning_rate)
default_doc += f"""## Training Schedule

{training_summary}
"""

if doc is None:
    doc = default_doc

torch_em.util.modelzoo.export_bioimageio_model(
    trainer, export_folder, input_optional_parameters=True,
    for_deepimagej=for_dij, training_data=training_data, documentation=doc
)
torch_em.util.modelzoo.add_weight_formats(export_folder, additional_weight_formats)
